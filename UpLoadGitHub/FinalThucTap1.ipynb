# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
plt.figure(figsize=[8, 5])

ba_133 = pd.read_excel('Ba-133.xlsx')

y_ba = (ba_133['Ba-133'][0:] /278) *300
x_ba = np.linspace(1, len(y_ba), len(y_ba))

plt.plot(x_ba, y_ba, color='red', label='Phổ Ba-133')
plt.xlim([20, 370])
plt.ylim([0, 40000])


# Peaks
counts_ba = [34216, 14064+900, 2926, 6740]
ch_ba = [30+1, 66+2, 242, 287]

plt.scatter(ch_ba, counts_ba, color='blue', label='Đỉnh năng lượng')

plt.title('Phổ Ba-133 số đếm theo kênh' + '\n' + 'Real Time: 323.00(s), Live Time: 300.00(s)', fontname='arial', fontsize=14)
plt.xlabel('Kênh (2048)', fontname='arial', fontsize=13)
plt.ylabel('Số đếm', fontname='arial', fontsize=13)
plt.legend(fontsize=13)

plt.text(40, 32000, 'Kênh: 31' + '\n' + 'Số đếm: 34216', fontname='arial', fontsize=11)
plt.text(75, 14064+900, 'Kênh: 68' + '\n' + 'Số đếm: 14965', fontname='arial', fontsize=11)
plt.text(200, 4000, 'Kênh: 242' + '\n' + 'Số đếm: 2926', fontname='arial', fontsize=11)
plt.text(300, 6500, 'Kênh: 287' + '\n' + 'Số đếm: 6740', fontname='arial', fontsize=11)
# Out:
# Text(300, 6500, 'Kênh: 287\nSố đếm: 6740')

# %%
ch_ba = [30, 66, 242, 287]
def counst():
    result= []
    for value in ch_ba:
        result.append(round(y_ba[value]))
    return result
print(counst())
# Out:
# [34216, 14064, 2926, 6740]

# %%
plt.figure(figsize=[8, 5])

cobalt_60 = pd.read_excel("cobalt-60.xlsx")

y_cb = cobalt_60['cobalt-60'][0:]
x_cb = np.linspace(1, len(y_cb), len(y_cb))

plt.plot(x_cb, y_cb, color='blue', label='Phổ Co-60')

# peaks
ch_co = [851, 962]
c_co = [972+10, 751+50]

plt.scatter(ch_co, c_co, color='red', label='Đỉnh năng lượng')

plt.xlim([0, 1100])
plt.ylim([0, 1600])

plt.title('Phổ Co-60 số đếm theo kênh' + '\n' + 'Real Time: 306.00(s), Live Time: 300.00(s)', fontname='arial', fontsize=14)
plt.xlabel('Kênh (2048)', fontname='arial', fontsize=13)
plt.ylabel('Số đếm', fontname='arial', fontsize=13)
plt.legend(fontsize=13)

plt.text(660, 970, 'Kênh: 851' + '\n' + 'Số đếm: 982', fontname='arial', fontsize=11)
plt.text(900, 880, 'Kênh: 962' + '\n' + 'Số đếm: 801', fontname='arial', fontsize=11)
# Out:
# Text(900, 880, 'Kênh: 962\nSố đếm: 801')

# %%
ch_co = [851, 962]
def counst():
    result= []
    for value in ch_co:
        result.append(round(y_cb[value]))
    return result
print(counst())
# Out:
# [972, 751]

# %%
plt.figure(figsize=[8, 5])

eu_152 = pd.read_excel('Eu-152.xlsx')

y_eu = eu_152['Eu-152'][0:]
x_eu = np.linspace(1, len(y_eu), len(y_eu))

plt.plot(x_eu, y_eu, color='green', label='Phổ Eu-152')

# peaks
c_eu = [34283+6000, 24997, 4757, 9479, 1413, 823, 1940, 2049]
ch_eu = [31+2, 93, 183, 256, 702, 1017, 796, 567]

plt.scatter(ch_eu, c_eu, color='blue', label='Đỉnh năng lượng')

plt.xlim([-10, 1100])
plt.ylim([0, 45000])

plt.title('Phổ Eu-152 số đếm theo kênh' + '\n' + 'Real Time: 332.00(s), Live Time: 300.00(s)', fontname='arial', fontsize=14)
plt.xlabel('Kênh (2048)', fontname='arial', fontsize=13)
plt.ylabel('Số đếm', fontname='arial', fontsize=13)
plt.legend(fontsize=13)

plt.text(50, 40000, 'Kênh: 33' + '\n' + 'Số đếm: 40283', fontname='arial', fontsize=11)
plt.text(120, 25000, 'Kênh: 100' + '\n' + 'Số đếm: 24997', fontname='arial', fontsize=11)
plt.text(280, 9000, 'Kênh: 256' + '\n' + 'Số đếm: 9479', fontname='arial', fontsize=11)
plt.text(280, 9000, 'Kênh: 256' + '\n' + 'Số đếm: 9479', fontname='arial', fontsize=11)
plt.text(800, 2900, 'Kênh: 796' + '\n' + 'Số đếm: 1940', fontname='arial', fontsize=11)
# Out:
# Text(800, 2900, 'Kênh: 796\nSố đếm: 1940')

# %%
ch_eu = [31, 93, 183, 256, 702, 1017, 796, 567]
def counst():
    result= []
    for value in ch_eu:
        result.append(round(y_eu[value]))
    return result
print(counst())
# Out:
# [34283, 24997, 4757, 9479, 1413, 823, 1940, 2049]

# %%
plt.figure(figsize=[8, 5])

# Ba-133
# E = 30.9731, 80.9979, 302.8508, 356.0129
# ch = 30, 66, 242, 287

# Cobalt-60
# E = 1173.228, 1332.492
# ch = 851, 962

# Eu-152
# E = 40.1186, 121.7817, 244.6974, 344.2785, 964.079, 1408.013, 1112.076, 778.9045
# ch = 31, 93, 183, 256, 702, 1017, 796, 567

e_sor = sorted([30.9731, 80.9979, 302.8508, 356.0129, 1173.228, 1332.492, 40.1186, 121.7817, 244.6974, 344.2785, 964.079, 1408.013, 1112.076, 778.9045])
ch_sor = sorted([30, 66, 242, 287, 851, 962, 31, 93, 183, 256, 702, 1017, 796, 567])

E = np.array([30.9731, 40.1186, 80.9979, 121.7817, 244.6974, 302.8508, 344.2785, 356.0129, 778.9045, 964.079, 1112.076, 1173.228, 1332.492, 1408.013])
ch = np.array([30, 31, 66, 93, 183, 242, 256, 287, 567, 702, 796, 851, 962, 1017])

fit = np.polyfit(ch, E, 1)
ch_sm = np.linspace(min(ch), max(ch), 1000)
yfit = fit[0]*ch_sm + fit[1]

#plt.scatter(ch, E, color='black', label='Data')
plt.plot(ch_sm, yfit, color='darkorange', label='Linear Fit')

y_in = fit[0]*ch + fit[1]
R2 = 1 - (sum((E-y_in)**2)) / (sum((E-np.mean(E))**2))
print("R^2 = " + str(round(R2,4)) )

print('E = ' + str(fit[0]) + 'x ' + str(fit[1]))

# scatter Ba-133
E_ba = [30.9731, 80.9979, 302.8508, 356.0129]
ch_ba = [30, 66, 242, 287]
plt.scatter(ch_ba, E_ba, color='red', label='Ba-133')

# scatter Co-60
E_co = [1173.228, 1332.492]
ch_co = [851, 962]
plt.scatter(ch_co, E_co, color='blue', label='Co-60')

#scatter Eu-152
E_eu = [40.1186, 121.7817, 244.6974, 344.2785, 778.9045, 964.079, 1112.076, 1408.013]
ch_eu = [31, 93, 183, 256, 567, 702, 796, 1017]
plt.scatter(ch_eu, E_eu, color='green', label='Eu-152')

plt.title('Phương trình chuẩn năng lượng', fontname='arial', fontsize=14)
plt.xlabel('Kênh', fontname='arial', fontsize=13)
plt.ylabel(r'Năng lượng $(keV)$', fontname='arial', fontsize=13)
plt.legend(fontsize=13)
plt.xlim([-10, 1100])
plt.ylim([-100, 1500])

plt.text(580, 600, r'E = ' + str(round(fit[0], 2)) + r'0$\times$ kênh - ' + str(abs(round(fit[1], 2))) + r' $(keV)$',
         fontsize=13, color='darkorange')
plt.text(580, 500, r'$R^2$ = ' + str(round(R2,4)), fontsize=13, color='darkorange')
# Out:
# R^2 = 0.9995
# E = 1.3998937123032853x -16.07500371006268
# Text(580, 500, '$R^2$ = 0.9995')

# %%
plt.figure(figsize=[8, 5])

xfit_ba = fit[0]*x_ba + fit[1]

plt.plot(xfit_ba - xfit_ba*0.08, y_ba, color="red", label='Phổ năng lượng Ba-133')
plt.xlim([0, 500])
plt.ylim([0, 40000])

c_ba = [34216, 14064+900, 2926, 6740]
E_ba = [30.9731-5, 80.9979-5, 302.8508, 356.0129]

plt.scatter(E_ba, c_ba, color='blue', label='Đỉnh năng lượng')


plt.title('Phổ Ba-133 số đếm theo năng lượng' + '\n' + 'Real Time: 323.00(s), Live Time: 300.00(s)', fontname='arial', fontsize=14)
plt.ylabel('Số Đếm', fontname='arial', fontsize=13)
plt.xlabel(r'Năng lượng $(keV)$', fontname='arial', fontsize=13)
plt.legend()

plt.text(38, 35216, '31 kev', fontname='arial', fontsize=11)
plt.text(90, 14064+900, '81 keV', fontname='arial', fontsize=11)
plt.text(250, 4000, '303 keV', fontname='arial', fontsize=11)
plt.text(356, 7500, '356 keV', fontname='arial', fontsize=11)
# Out:
# Text(356, 7500, '356 keV')

# %%
plt.figure(figsize=[8, 5])

xfit_cb = fit[0]*x_cb + fit[1]

plt.plot(xfit_cb, y_cb, color="blue", label='Phổ năng lượng Co-60')
plt.xlim([0, 1600])
plt.ylim([0, 1600])

E_co = [1173.228, 1332.492]
c_co = [972+10, 751+50]
plt.scatter(E_co, c_co, color='red', label='Đỉnh năng lượng')


plt.title('Phổ Cobalt-60 số đếm theo năng lượng' + '\n' + 'Real Time: 306.00(s), Live Time: 300.00(s)', fontname='arial', fontsize=14)
plt.ylabel('Số Đếm', fontname='arial', fontsize=13)
plt.xlabel(r'Năng lượng $(keV)$', fontname='arial', fontsize=13)

plt.text(1050, 1050, '1173 kev', fontname='arial', fontsize=11)
plt.text(1300, 850, '1332 keV', fontname='arial', fontsize=11)
plt.legend()

# %%
plt.figure(figsize=[8, 5])

xfit_eu = fit[0]*x_eu + fit[1]

plt.plot(xfit_eu, y_eu, color="green", label='Phổ năng lượng Eu-152')
plt.xlim([0, 1600])
plt.ylim([-200, 45000])

plt.title('Phổ Eu-152 số đếm theo năng lượng' + '\n' + 'Real Time: 332.00(s), Live Time: 300.00(s)', fontname='arial', fontsize=14)
plt.ylabel('Số Đếm', fontname='arial', fontsize=13)
plt.xlabel(r'Năng lượng $(keV)$', fontname='arial', fontsize=13)

E_eu = [40.1186-8, 121.7817-10, 244.6974, 344.2785, 778.9045, 964.079, 1112.076, 1408.013]
c_eu = [34283+6000, 24997, 4757, 9479+500, 1413+400, 823+600, 1940, 2049-1000]

plt.scatter(E_eu, c_eu, color='blue', label='đỉnh năng lượng')

plt.text(60, 40000, '40 KeV', fontname='arial', fontsize=11)
plt.text(140, 25000, '122 keV', fontname='arial', fontsize=11)
plt.text(150, 6479, '225 keV', fontname='arial', fontsize=11)
plt.text(280, 9000+2000, '334 keV', fontname='arial', fontsize=11)
plt.text(700, 1413+400+1000, '779 keV', fontname='arial', fontsize=11)
plt.text(900, 823+600+1000, '965 keV', fontname='arial', fontsize=11)
plt.text(1100, 1940+1000, '1112 keV', fontname='arial', fontsize=11)
plt.text(1400, 2049, '1408 keV', fontname='arial', fontsize=11)
# Out:
# Text(1400, 2049, '1408 keV')

# %%
# Eu-152
# E = 40.1186, 121.7817, 244.6974, 344.2785, 964.079, 1408.013, 1112.076, 778.9045
# ch = 31, 93, 183, 256, 702, 1017, 796, 567
sorted([31, 93, 183, 256, 702, 1017, 796, 567])
# Out:
# [31, 93, 183, 256, 567, 702, 796, 1017]
